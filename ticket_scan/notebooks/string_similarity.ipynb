# %% [markdown]
# ## Imports

# %%
import regex
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz

# %% [markdown]
# ## Variable definition

# %%
possible_outputs = {
  "3.0_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NNF: A-46103834",
    "5": "1/03/2019 19:51.  0P: 105936",
    "6": "MACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFY 1,22 3,06",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.173",
    "14": "1 ZANAHORIA BOLS 6,079",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "GLTALLE (\u20ac)",
    "25": "yA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HTAL 4339 3,56",
    "30": "LAR]: rr GO 16",
    "31": "AUT: 307029",
    "32": "\u00abLl: 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abISA CLASICA",
    "36": "\"130",
    "37": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "3.0_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF: A-46103934",
    "5": "17/03/2019 19:51  0P; 105936",
    "6": "+ACTURA SIMPLIFICADA: 2308-011-u43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB DTS)",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "LLTALLE (\u20ac)",
    "25": "I/A BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HUTAL 43,97 3,56",
    "30": "LAR: aa 90 16",
    "31": "AUT: 307029",
    "32": "\u201cu.L:; 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abIYA CL\u00c1SICA",
    "36": "\u201c130",
    "37": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "3.0_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NAF: A-46103834",
    "5": "17/03/2019 19:51  0P: 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u, qu",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "TARJETA. BANCARIA 46,3",
    "24": "ILTALLE (\u20ac)",
    "25": "IA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "y113 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "DAR\u00cdO rra 90 16",
    "31": "AUT: 307029",
    "32": "\u201cLL: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4000000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "130",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "3.0_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "7/03/2019 19:51 OP: 1059346",
    "6": "FACTURA SIMPLIFICADA: 2308-011-v43UTO",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 \u20ace/kg 1,41",
    "22": "TOTAL 463%",
    "23": "TARJETA. BANCARIA 46%",
    "24": "LLTALLE (\u20ac)",
    "25": "1vA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HITAL 43,9 3,56",
    "30": "LARJ: 9016",
    "31": "AUT: 307029",
    "32": "\u201cul: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4490000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "130",
    "37": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "3.0_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ONIFE\u2014\u2014 A-46103834",
    "5": "17/03/2019 19:51 OP: 109936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-143U 1",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "0,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLAFANO '",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL 43",
    "23": "TARJETA. BANCARIA 46,3%",
    "24": "LLTALLE (\u20ac)",
    "25": "1YA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "21% 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "IN",
    "31": "AUT: 307029",
    "32": "uE; 44101236 o",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4100000031010 o",
    "35": "\u00ab1UA CLASICA",
    "36": "3",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "3.0_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF A-46103834",
    "5": "17/63/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-611-643U1",
    "7": "Preciv Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22. 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA AT\u00daN. 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,07",
    "18": "1 PEPINO y o",
    "19": "U,478 kg 1,89 \u20ac/kg y,",
    "20": "1 PLATANO o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "TARJETA, BANCARIA 46,8",
    "24": "LILTALLE (\u20ac)",
    "25": "IVA BASE IMPONIBLE CUOTA",
    "26": "4 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2% 3,94 0,83",
    "29": "DUTAL 43,97 3,56",
    "30": "A",
    "31": "AUT: 307029",
    "32": "uz 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": "- YUYODO3 101",
    "35": "\u00ab13A CLASICA",
    "36": "130",
    "37": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  },
  "3.5_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NNF: A-46103834",
    "5": "1/03/2019 19:51.  0P: 105936",
    "6": "MACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFY 1,22 3,06",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.173",
    "14": "1 ZANAHORIA BOLS 6,079",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "GLTALLE (\u20ac)",
    "25": "yA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HTAL 4339 3,56",
    "30": "LAR]: rr GO 16",
    "31": "AUT: 307029",
    "32": "\u00abLl: 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abISA CLASICA",
    "36": "\"130",
    "37": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "3.5_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF: A-46103934",
    "5": "17/03/2019 19:51  0P; 105936",
    "6": "+ACTURA SIMPLIFICADA: 2308-011-u43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB DTS)",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "LLTALLE (\u20ac)",
    "25": "I/A BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HUTAL 43,97 3,56",
    "30": "LAR: aa 90 16",
    "31": "AUT: 307029",
    "32": "\u201cu.L:; 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abIYA CL\u00c1SICA",
    "36": "\u201c130",
    "37": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "3.5_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NAF: A-46103834",
    "5": "17/03/2019 19:51  0P: 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u, qu",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "TARJETA. BANCARIA 46,3",
    "24": "ILTALLE (\u20ac)",
    "25": "IA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "y113 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "DAR\u00cdO rra 90 16",
    "31": "AUT: 307029",
    "32": "\u201cLL: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4000000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "130",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "3.5_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "7/03/2019 19:51 OP: 1059346",
    "6": "FACTURA SIMPLIFICADA: 2308-011-v43UTO",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 \u20ace/kg 1,41",
    "22": "TOTAL 463%",
    "23": "TARJETA. BANCARIA 46%",
    "24": "LLTALLE (\u20ac)",
    "25": "1vA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HITAL 43,9 3,56",
    "30": "LARJ: 9016",
    "31": "AUT: 307029",
    "32": "\u201cul: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4490000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "130",
    "37": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "3.5_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ONIFE\u2014\u2014 A-46103834",
    "5": "17/03/2019 19:51 OP: 109936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-143U 1",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "0,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLAFANO '",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL 43",
    "23": "TARJETA. BANCARIA 46,3%",
    "24": "LLTALLE (\u20ac)",
    "25": "1YA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "21% 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "IN",
    "31": "AUT: 307029",
    "32": "uE; 44101236 o",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4100000031010 o",
    "35": "\u00ab1UA CLASICA",
    "36": "3",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "3.5_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF A-46103834",
    "5": "17/63/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-611-643U1",
    "7": "Preciv Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22. 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA AT\u00daN. 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,07",
    "18": "1 PEPINO y o",
    "19": "U,478 kg 1,89 \u20ac/kg y,",
    "20": "1 PLATANO o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "TARJETA, BANCARIA 46,8",
    "24": "LILTALLE (\u20ac)",
    "25": "IVA BASE IMPONIBLE CUOTA",
    "26": "4 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2% 3,94 0,83",
    "29": "DUTAL 43,97 3,56",
    "30": "A",
    "31": "AUT: 307029",
    "32": "uz 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": "- YUYODO3 101",
    "35": "\u00ab13A CLASICA",
    "36": "130",
    "37": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  },
  "4.0_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NNF: A-46103834",
    "5": "1/03/2019 19:51.  0P: 105936",
    "6": "MACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFV 1,22 3,06",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.7",
    "14": "1 ZANAHORIA BOLS 6,079",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGIENICO DOBL \u00a3,Ul",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "GLTALLE (\u20ac)",
    "25": "a BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HTAL 4339 3,56",
    "30": "LAR]: rr GO 16",
    "31": "AUT: 307029",
    "32": "\u00abLl: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abISA CLASICA",
    "36": "\u201c4130",
    "37": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "4.0_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF: A-46103934",
    "5": "17/03/2019 19:51  0P; 105936",
    "6": "+ACTURA SIMPLIFICADA: 2308-011-u43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB 3:13",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "LLTALLE (\u20ac)",
    "25": "ya BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HUTAL 43,97 3,56",
    "30": "LAR: aa 90 16",
    "31": "AUT: 307029",
    "32": "\u201cu.L:; 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abIYA CL\u00c1SICA",
    "36": "130",
    "37": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "4.0_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NAF: A-46103834",
    "5": "17/03/2019 19:51  0P: 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3/34",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u, qu",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "TARJETA. BANCARIA 46,3",
    "24": "ILTALLE (\u20ac)",
    "25": "I/A BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "y113 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "DAR\u00cdO rra 90 16",
    "31": "AUT: 307029",
    "32": "\u201cLL: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4000000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "\u201c130",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "4.0_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "7/03/2019 19:51 OP: 1059346",
    "6": "FACTURA SIMPLIFICADA: 2308-011-v43UTO",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 \u20ace/kg 1,41",
    "22": "TOTAL 463%",
    "23": "TARJETA. BANCARIA 46%",
    "24": "LLTALLE (\u20ac)",
    "25": "IA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HITAL 43,9 3,56",
    "30": "LARJ: 9016",
    "31": "AUT: 307029",
    "32": "\u201cul: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4490000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "30",
    "37": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "4.0_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ONIFE\u2014\u2014 A-46103834",
    "5": "17/03/2019 19:51 OP: 109936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-143U 1",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEY 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "0,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLAFANO '",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL 43",
    "23": "TARJETA. BANCARIA 46,3%",
    "24": "LLTALLE (\u20ac)",
    "25": "1vA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "21% 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "IN",
    "31": "AUT: 307029",
    "32": "uE; 44101236 o",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4100000031010 o",
    "35": "\u00ab1UA CLASICA",
    "36": "3",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "4.0_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF A-46103834",
    "5": "17/63/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-611-643U1",
    "7": "Preciv Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,66",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA AT\u00daN. 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO y o",
    "19": "U,478 kg 1,89 \u20ac/kg y,",
    "20": "1 PLATANO o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "TARJETA, BANCARIA 46,8",
    "24": "LILTALLE (\u20ac)",
    "25": "1YA BASE IMPONIBLE CUOTA",
    "26": "4 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2% 3,94 0,83",
    "29": "DUTAL 43,97 3,56",
    "30": "A",
    "31": "AUT: 307029",
    "32": "uz 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": "- YUYODO3 101",
    "35": "\u00ab13A CLASICA",
    "36": "130",
    "37": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  },
  "4.5_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NNF: A-46103834",
    "5": "1/03/2019 19:51.  0P: 105936",
    "6": "MACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFV 1,22 3,06",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.7",
    "14": "1 ZANAHORIA BOLS 6,079",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGIENICO DOBL \u00a3,Ul",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "GLTALLE (\u20ac)",
    "25": "a BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HTAL 4339 3,56",
    "30": "LAR]: rr GO 16",
    "31": "AUT: 307029",
    "32": "\u00abLl: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abISA CLASICA",
    "36": "\u201c4130",
    "37": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "4.5_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF: A-46103934",
    "5": "17/03/2019 19:51  0P; 105936",
    "6": "+ACTURA SIMPLIFICADA: 2308-011-u43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB 3:13",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL. 49",
    "23": "TARJETA. BANCARIA 469%",
    "24": "LLTALLE (\u20ac)",
    "25": "ya BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HUTAL 43,97 3,56",
    "30": "LAR: aa 90 16",
    "31": "AUT: 307029",
    "32": "\u201cu.L:; 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4400000031010",
    "35": "\u00abIYA CL\u00c1SICA",
    "36": "130",
    "37": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "4.5_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NAF: A-46103834",
    "5": "17/03/2019 19:51  0P: 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3/34",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u, qu",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "TARJETA. BANCARIA 46,3",
    "24": "ILTALLE (\u20ac)",
    "25": "I/A BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "y113 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "DAR\u00cdO rra 90 16",
    "31": "AUT: 307029",
    "32": "\u201cLL: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": ". 4000000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "\u201c130",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "4.5_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "7/03/2019 19:51 OP: 1059346",
    "6": "FACTURA SIMPLIFICADA: 2308-011-v43UTO",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 \u20ace/kg 1,41",
    "22": "TOTAL 463%",
    "23": "TARJETA. BANCARIA 46%",
    "24": "LLTALLE (\u20ac)",
    "25": "IA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2 3,94 0,83",
    "29": "HITAL 43,9 3,56",
    "30": "LARJ: 9016",
    "31": "AUT: 307029",
    "32": "\u201cul: 44101236",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4490000031010",
    "35": "\u00abIVA CL\u00c1SICA",
    "36": "30",
    "37": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "4.5_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ONIFE\u2014\u2014 A-46103834",
    "5": "17/03/2019 19:51 OP: 109936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-143U 1",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEY 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "0,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLAFANO '",
    "21": "0,616 kg 2,29 e/kg 1,91",
    "22": "TOTAL 43",
    "23": "TARJETA. BANCARIA 46,3%",
    "24": "LLTALLE (\u20ac)",
    "25": "1vA BASE IMPONIBLE CUOTA",
    "26": "4% 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "21% 3,94 0,83",
    "29": "HITAL 43,97 3,56",
    "30": "IN",
    "31": "AUT: 307029",
    "32": "uE; 44101236 o",
    "33": "+ PALO TARJETA BANCARIA +",
    "34": "- 4100000031010 o",
    "35": "\u00ab1UA CLASICA",
    "36": "3",
    "37": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "4.5_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF A-46103834",
    "5": "17/63/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-611-643U1",
    "7": "Preciv Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,66",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA AT\u00daN. 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO y o",
    "19": "U,478 kg 1,89 \u20ac/kg y,",
    "20": "1 PLATANO o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "TARJETA, BANCARIA 46,8",
    "24": "LILTALLE (\u20ac)",
    "25": "1YA BASE IMPONIBLE CUOTA",
    "26": "4 20,19 0,81",
    "27": "10% 19,24 1,92",
    "28": "2% 3,94 0,83",
    "29": "DUTAL 43,97 3,56",
    "30": "A",
    "31": "AUT: 307029",
    "32": "uz 44101236",
    "33": "+ PAGO TARJETA BANCARIA +",
    "34": "- YUYODO3 101",
    "35": "\u00ab13A CLASICA",
    "36": "130",
    "37": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  },
  "5.0_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NIF: A-46103834",
    "5": "1/03/2019 19:51.  0P: 105936",
    "6": "FACTURA SIMPLIFICADA: 2300-011-U43UT",
    "7": "Prectu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFV 1,22 3,06",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.7",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,350",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGIENICO DOBL \u00a3,Ul",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,yU",
    "20": "1 PLATANO",
    "21": "0,6l6bkg 2,29 \u20ac/kg 1,41",
    "22": "TAL. 49",
    "23": "GLTALLE (\u20ac)",
    "24": "JA BASE IMPONIBLE CUD\u00cdA",
    "25": "34% 20,19 0,81",
    "26": "10% 19,24 1.92",
    "27": "ZN 3,94 0,83",
    "28": "HTAL 4339 3,56",
    "29": "LAR]: rr GO 16",
    "30": "AUT: 307029",
    "31": "\u00abLl: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abISA CLASICA",
    "35": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "5.0_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NNF: A-46103834",
    "5": "17/03/2019 19:51  0P; 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43U16",
    "7": "Preclu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB 3:13",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 \u20ac/ky 1,41",
    "22": "TOTAL. 49",
    "23": "LLTALLE (\u20ac)",
    "24": "yA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HUTAL 43,97 3,56",
    "29": "LAR: aa 90 16",
    "30": "AUT: 307029",
    "31": "\u201cu.L:; 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abIYA CL\u00c1SICA",
    "35": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "5.0_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF; A-46103834",
    "5": "17/03/2019 19:51  0P: 105936",
    "6": "+ACIURA SIMPLIFICADA: 2308-011-v43u Te",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3/34",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,9u",
    "20": "1 PLATANO",
    "21": "0,6l16kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "ILTALLE (\u20ac)",
    "24": "I/A BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "DAR\u00cdO rra 90 16",
    "30": "AUT: 307029",
    "31": "\u201cLL: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4000000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "5.0_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ON A-46103834",
    "5": "7/03/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-01 1-vAGUTO",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 463%",
    "23": "LLTALLE (\u20ac)",
    "24": "IA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "y113 3,94 0,83",
    "28": "HITAL 43,9 3,56",
    "29": "LARJ: 9016",
    "30": "AUT: 307029",
    "31": "\u201cul: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4490000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "5.0_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "17/03/2019 19:51 OP: 109936",
    "6": "FACTURA SIMPLIFICADA: 2308-0011-643U10",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEY 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLAFANO '",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 43",
    "23": "LLTALLE (\u20ac)",
    "24": "1vA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "IN",
    "30": "AUT: 307029",
    "31": "uE; 44101236 o",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4100000031010 o",
    "34": "\u00ab1UA CLASICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "5.0_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF: A-46103834",
    "5": "17/63/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-011-643UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,66",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO y o",
    "19": "0,418 kg 1,89 \u20ac/kg ug",
    "20": "1 PLATANO o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "LILTALLE (\u20ac)",
    "24": "1YA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "DUTAL 43,97 3,56",
    "29": "A",
    "30": "AUT: 307029",
    "31": "uz 44101236",
    "32": "+ PAGO TARJETA BANCARIA +",
    "33": "- YUYODO3 101",
    "34": "\u00ab13A CLASICA",
    "35": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  },
  "5.5_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NIF: A-46103834",
    "5": "1/03/2019 19:51.  0P: 105936",
    "6": "FACTURA SIMPLIFICADA: 2300-011-U43UT",
    "7": "Prectu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFV 1,22 3,06",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.7",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,350",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGIENICO DOBL \u00a3,Ul",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,yU",
    "20": "1 PLATANO",
    "21": "0,6l6bkg 2,29 \u20ac/kg 1,41",
    "22": "TAL. 49",
    "23": "GLTALLE (\u20ac)",
    "24": "JA BASE IMPONIBLE CUD\u00cdA",
    "25": "34% 20,19 0,81",
    "26": "10% 19,24 1.92",
    "27": "ZN 3,94 0,83",
    "28": "HTAL 4339 3,56",
    "29": "LAR]: rr GO 16",
    "30": "AUT: 307029",
    "31": "\u00abLl: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abISA CLASICA",
    "35": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "5.5_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NNF: A-46103834",
    "5": "17/03/2019 19:51  0P; 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43U16",
    "7": "Preclu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB 3:13",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 \u20ac/ky 1,41",
    "22": "TOTAL. 49",
    "23": "LLTALLE (\u20ac)",
    "24": "yA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HUTAL 43,97 3,56",
    "29": "LAR: aa 90 16",
    "30": "AUT: 307029",
    "31": "\u201cu.L:; 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abIYA CL\u00c1SICA",
    "35": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "5.5_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF; A-46103834",
    "5": "17/03/2019 19:51  0P: 105936",
    "6": "+ACIURA SIMPLIFICADA: 2308-011-v43u Te",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3/34",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,9u",
    "20": "1 PLATANO",
    "21": "0,6l16kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "ILTALLE (\u20ac)",
    "24": "I/A BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "DAR\u00cdO rra 90 16",
    "30": "AUT: 307029",
    "31": "\u201cLL: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4000000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "5.5_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ON A-46103834",
    "5": "7/03/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-01 1-vAGUTO",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 463%",
    "23": "LLTALLE (\u20ac)",
    "24": "IA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "y113 3,94 0,83",
    "28": "HITAL 43,9 3,56",
    "29": "LARJ: 9016",
    "30": "AUT: 307029",
    "31": "\u201cul: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4490000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "5.5_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "17/03/2019 19:51 OP: 109936",
    "6": "FACTURA SIMPLIFICADA: 2308-0011-643U10",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEY 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLAFANO '",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 43",
    "23": "LLTALLE (\u20ac)",
    "24": "1vA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "IN",
    "30": "AUT: 307029",
    "31": "uE; 44101236 o",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4100000031010 o",
    "34": "\u00ab1UA CLASICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "5.5_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF: A-46103834",
    "5": "17/63/2019 19:51 OP: 1059346",
    "6": "HACTURA SIMPLIFICADA: 2308-011-643UT6",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,66",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO y o",
    "19": "0,418 kg 1,89 \u20ac/kg ug",
    "20": "1 PLATANO o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "LILTALLE (\u20ac)",
    "24": "1YA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "DUTAL 43,97 3,56",
    "29": "A",
    "30": "AUT: 307029",
    "31": "uz 44101236",
    "32": "+ PAGO TARJETA BANCARIA +",
    "33": "- YUYODO3 101",
    "34": "\u00ab13A CLASICA",
    "35": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  },
  "6.0_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NIF: A-46103834",
    "5": "1/0/2019 19:51.  0P; 105936",
    "6": "LACTURA SIMPLIFICADA: 2308-011-643U16",
    "7": "Prectu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFV 1,22 3,bb",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.7",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,38",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGIENICO DOBL \u00a3,Ul",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANU",
    "21": "0,6l6bkg 2,29 \u20ac/kg 1,41",
    "22": "TAL. 49",
    "23": "GLTALLE (\u20ac)",
    "24": "JA BASE IMPONIBLE CUD\u00cdA",
    "25": "34% 20,19 0,81",
    "26": "10% 19,24 1.92",
    "27": "ZN 3,94 0,83",
    "28": "HTAL 4339 3,56",
    "29": "LAR]: 9010",
    "30": "AUT: 307029",
    "31": "\u00abLl: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abISA CLASICA",
    "35": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "6.0_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NNF: A-46103834",
    "5": "w//03/2019 19:51. OP: 105936",
    "6": "MACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preclu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEY 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB 3:13",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN Ly ld 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANU",
    "21": "0,616 kg 2,29 \u20ac/ky 1,41",
    "22": "TOTAL. 49",
    "23": "LLTALLE (\u20ac)",
    "24": "yA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HUTAL 43,97 3,56",
    "29": "ARS: rr gO 10",
    "30": "AUT: 307029",
    "31": "\u201cu.L:; 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abIYA CL\u00c1SICA",
    "35": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "6.0_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF; A-46103834",
    "5": "17/03/2019 19:51.  0P: 1059346",
    "6": "+ACTURA SIMPLIFICADA: 2308-011-u43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3/34",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2 19) 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANO",
    "21": "0,6l16kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "ILTALLE (\u20ac)",
    "24": "I/A BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "LARJ: rr 9016",
    "30": "AUT: 307029",
    "31": "\u201cLL: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4000000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "6.0_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ON A-46103834",
    "5": "17/03/2019 19:51 OP: 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u, qu",
    "20": "1 PLAFANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 463%",
    "23": "LLTALLE (\u20ac)",
    "24": "IA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "y113 3,94 0,83",
    "28": "HITAL 43,9 3,56",
    "29": "LARJ: 9016",
    "30": "AUT: 307029",
    "31": "\u201cul: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4490000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "6.0_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "7/03/2019 19:51. OP: 105936.",
    "6": "FACTURA SIMPLIFICADA: 2308-011-v43UTO",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEV 1,22 3,56",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO '",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 43",
    "23": "LLTALLE (\u20ac)",
    "24": "1vA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "IN",
    "30": "AUT: 307029",
    "31": "uE; 44101236 o",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4100000031010 o",
    "34": "\u00ab1UA CLASICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "6.0_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF: A-46103834",
    "5": "17/03/2019 19:51. OP: 105946.",
    "6": "HACTURA SIMPLIFICADA: 2308-011-143U 1",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "0,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLATANO o o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "LILTALLE (\u20ac)",
    "24": "1YA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "DUTAL 43,97 3,56",
    "29": "o",
    "30": "AUT: 307029",
    "31": "uz 44101236",
    "32": "+ PAGO TARJETA BANCARIA +",
    "33": "- YUYODO3 101",
    "34": "\u00ab13A CLASICA",
    "35": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  },
  "6.5_2": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARDO",
    "2": "MURCIA",
    "3": "TELEFONO: 908307114",
    "4": "NIF: A-46103834",
    "5": "1/0/2019 19:51.  0P; 105936",
    "6": "LACTURA SIMPLIFICADA: 2308-011-643U16",
    "7": "Prectu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B, ALMENDRA S/A E\u00a3,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELIFV 1,22 3,bb",
    "12": "1 COPOS AVENA 0,bl",
    "13": "1 COSTILLA BARB 3.7",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN 2,15 4,38",
    "16": "1 PAPEL HIGIENIC 4,",
    "17": "1 HIGIENICO DOBL \u00a3,Ul",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANU",
    "21": "0,6l6bkg 2,29 \u20ac/kg 1,41",
    "22": "TAL. 49",
    "23": "GLTALLE (\u20ac)",
    "24": "JA BASE IMPONIBLE CUD\u00cdA",
    "25": "34% 20,19 0,81",
    "26": "10% 19,24 1.92",
    "27": "ZN 3,94 0,83",
    "28": "HTAL 4339 3,56",
    "29": "LAR]: 9010",
    "30": "AUT: 307029",
    "31": "\u00abLl: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abISA CLASICA",
    "35": "SE ADMLIEN DEVOLUCTONES CON TICKEf"
  },
  "6.5_3": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARCO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NNF: A-46103834",
    "5": "w//03/2019 19:51. OP: 105936",
    "6": "MACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preclu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEY 1,22 3,06",
    "12": "1 COPOS AVENA 0,01",
    "13": "1 COSTILLA BARB 3:13",
    "14": "1 ZANAHORIA BOLS 6,09",
    "15": "2 VENTRESCA ATUN Ly ld 4,30",
    "16": "1 PAPEL HIGIENIC 4,50",
    "17": "1 HIGI\u00c9NICO DOBL ZU!",
    "18": "1 PEPINO",
    "19": "0,478 ky 1,89 \u20ac/kg u,9U",
    "20": "1 PLATANU",
    "21": "0,616 kg 2,29 \u20ac/ky 1,41",
    "22": "TOTAL. 49",
    "23": "LLTALLE (\u20ac)",
    "24": "yA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HUTAL 43,97 3,56",
    "29": "ARS: rr gO 10",
    "30": "AUT: 307029",
    "31": "\u201cu.L:; 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4400000031010",
    "34": "\u00abIYA CL\u00c1SICA",
    "35": "SE ADMITEN DEVOLUCTONES CON TICKEf"
  },
  "6.5_4": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF; A-46103834",
    "5": "17/03/2019 19:51.  0P: 1059346",
    "6": "+ACTURA SIMPLIFICADA: 2308-011-u43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3/34",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2 19) 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u,qU",
    "20": "1 PLATANO",
    "21": "0,6l16kg 2,29 e/kg 1,41",
    "22": "TOTAL 439",
    "23": "ILTALLE (\u20ac)",
    "24": "I/A BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "LARJ: rr 9016",
    "30": "AUT: 307029",
    "31": "\u201cLL: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": ". 4000000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "6.5_5": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "ON A-46103834",
    "5": "17/03/2019 19:51 OP: 105936",
    "6": "HACTURA SIMPLIFICADA: 2308-011-v43UT6",
    "7": "Preciu Importe",
    "8": "Vescr ipci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGIENICO DOBL 2,01",
    "18": "1 PEPINO",
    "19": "U,478 ky 1,89 \u20ac/kg u, qu",
    "20": "1 PLAFANO",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 463%",
    "23": "LLTALLE (\u20ac)",
    "24": "IA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "y113 3,94 0,83",
    "28": "HITAL 43,9 3,56",
    "29": "LARJ: 9016",
    "30": "AUT: 307029",
    "31": "\u201cul: 44101236",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4490000031010",
    "34": "\u00abIVA CL\u00c1SICA",
    "35": "SE ADMIIEN DEVOLUCIONES CON TICKEf"
  },
  "6.5_6": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": ". MURCIA",
    "3": "TELEFONO: 968307114",
    "4": "NIF. A-46103834",
    "5": "7/03/2019 19:51. OP: 105936.",
    "6": "FACTURA SIMPLIFICADA: 2308-011-v43UTO",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 186,00",
    "11": "3 GALLETA RELTEV 1,22 3,56",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 6,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "U,478 ky 1,89 \u20ac/kg u,9uU",
    "20": "1 PLATANO '",
    "21": "0,616 kg 2,29 e/kg 1,41",
    "22": "TOTAL 43",
    "23": "LLTALLE (\u20ac)",
    "24": "1vA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "HITAL 43,97 3,56",
    "29": "IN",
    "30": "AUT: 307029",
    "31": "uE; 44101236 o",
    "32": "+ PALO TARJETA BANCARIA +",
    "33": "- 4100000031010 o",
    "34": "\u00ab1UA CLASICA",
    "35": "SE ADMIIEN DEVOLUCTONES CON TICKEf"
  },
  "6.5_7": {
    "0": "MERCADONA S.A.",
    "1": "C/ MAYOR, 7 - ESPINARLO",
    "2": "o MURCIA",
    "3": "TELEFONO; 9568307114",
    "4": "NIF: A-46103834",
    "5": "17/03/2019 19:51. OP: 105946.",
    "6": "HACTURA SIMPLIFICADA: 2308-011-143U 1",
    "7": "Preciu Importe",
    "8": "Vescripci\u00f3n unidad (\u20ac)",
    "9": "1 B,ALMENDRA S/A 8,40",
    "10": "4 L SEMI S/LACTO 4,50 16,00",
    "11": "3 GALLETA RELTEV 1,22 3,06",
    "12": "1 COPOS AVENA 0,81",
    "13": "1 COSTILLA BARB 3,99",
    "14": "1 ZANAHORIA BOLS 0,69",
    "15": "2 VENTRESCA ATUN 2,15 4,30",
    "16": "1 PAPEL HIGIENIC 2,70",
    "17": "1 HIGI\u00c9NICO DOBL 2,07",
    "18": "1 PEPINO o",
    "19": "0,478 ky 1,89 \u20ac/kg u, 9",
    "20": "1 PLATANO o o",
    "21": "0,616 kg 2,29 e/ky 1,41",
    "22": "TOTAL 49",
    "23": "LILTALLE (\u20ac)",
    "24": "1YA BASE IMPONIBLE CUOTA",
    "25": "4% 20,19 0,81",
    "26": "10% 19,24 1,92",
    "27": "2% 3,94 0,83",
    "28": "DUTAL 43,97 3,56",
    "29": "o",
    "30": "AUT: 307029",
    "31": "uz 44101236",
    "32": "+ PAGO TARJETA BANCARIA +",
    "33": "- YUYODO3 101",
    "34": "\u00ab13A CLASICA",
    "35": "SE ADMLIEN DEVOLUCIONES CON TiCkEf"
  }
}
df_outputs = pd.DataFrame(possible_outputs)

# %%
df_outputs.to_csv("possible_ouptuts.csv", sep=";")

# %%
frase_lim_sup = "Descripción unidad (€)"
frase_lim_inf = "TOTAL"
th = 75

# %% [markdown]
# ### Localización de límite superior e inferior de lineas

# %%
for key in possible_outputs.keys():
    print("ticket", key)
    for line in possible_outputs[key].values():
        # print(fuzz.ratio(frase_lim_sup, line), "->", line)
        rat_lim_sup = fuzz.ratio(frase_lim_sup, line)
        rat_lim_inf = fuzz.ratio(frase_lim_inf, line)
        if rat_lim_inf > 50:
            print(frase_lim_inf, "->", line)
        if rat_lim_sup > 50:
            print(frase_lim_sup, "->", line)
    print()
# Out:
# ticket 0.0_2
#
# ticket 0.0_3
#
# ticket 0.0_4
#
# ticket 0.0_5
#
# ticket 0.0_6
#
# ticket 0.0_7
#
# ticket 1.5_2
# Descripción unidad (€) -> Vescripción unidad (€)
# TOTAL -> TOTAL. 439
#
# ticket 1.5_3
# Descripción unidad (€) -> Vescripción unidad (€)
# TOTAL -> TOTAL 463%
#
# ticket 1.5_4
# Descripción unidad (€) -> Vescripción unidad (€)
# TOTAL -> TOTAL 43
#
# ticket 1.5_5
# Descripción unidad (€) -> Vescripción unidad (€)
# TOTAL -> TOTAL 49
#
# ticket 1.5_6
# Descripción unidad (€) -> Vescripción unidad (€)
#
# ticket 1.5_7
# Descripción unidad (€) -> - Vescripción unidad (€)
#
# ticket 3.0_2
# Descripción unidad (€) -> Vescr ipción unidad (€)
#
# ticket 3.0_3
# Descripción unidad (€) -> Vescripción unidad (€)
# TOTAL -> TOTAL. 49
#
# ticket 3.0_4
# Descripción unidad (€) -> Vescripción unidad (€)
# TOTAL -> TOTAL 439
#
# ticket 3.0_5
# Descripción unidad (€) -> Vescr ipción unidad (€)
# TOTAL -> TOTAL 463%
#
# ticket 3.0_6
# Descripción unidad (€) -> Vescripción unidad (€)
# ...

# %% [markdown]
# ### Análisis de los distintos escaneos

# %%
"3.0_2".split("_")
# Out:
# ['3.0', '2']

# %%
df_analysis = pd.DataFrame({"threshold":[], "line_padding":[], "num_lines_detected":[]})
# Out:
# Empty DataFrame
# Columns: [threshold, line_padding, num_lines_detected]
# Index: []

# %%
for key in possible_outputs.keys():
    df_analysis = df_analysis.append(
        {
            "threshold": key.split("_")[0], 
            "line_padding":key.split("_")[1],
            "num_lines_detected": len(possible_outputs[key])
        },
        ignore_index=True,
    )
df_analysis
# Out:
#    threshold line_padding  num_lines_detected
# 0        3.0            2                38.0
# 1        3.0            3                38.0
# 2        3.0            4                38.0
# 3        3.0            5                38.0
# 4        3.0            6                38.0
# 5        3.0            7                38.0
# 6        3.5            2                38.0
# 7        3.5            3                38.0
# 8        3.5            4                38.0
# 9        3.5            5                38.0
# 10       3.5            6                38.0
# 11       3.5            7                38.0
# 12       4.0            2                38.0
# 13       4.0            3                38.0
# 14       4.0            4                38.0
# 15       4.0            5                38.0
# 16       4.0            6                38.0
# 17       4.0            7                38.0
# 18       4.5            2                38.0
# ...
